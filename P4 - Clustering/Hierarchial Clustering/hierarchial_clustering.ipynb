# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('./Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values

# %% [markdown]
# #### Using Dendogram to find the optimal number of clusters

# %%
from scipy.cluster import hierarchy as shc # TO GET DENDROGRAM
dendo = shc.dendrogram(shc.linkage(X, method = "ward")) 
# METHOD IS THE METHOD TO CALCULATE DISTANCE BETWEEN VARIOUS CLUSTERS

plt.title("Dendogram Plot")
plt.xlabel('Customers')
plt.ylabel('Distances')

plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
## FUNCTION(NO_OF-CLUSTERS, DISTANCE FORUMLA, LINKING)
cls = AgglomerativeClustering(n_clusters=5, affinity= 'euclidean',linkage='ward')
## WE WANT THE MODEL TO TRAIN AND BE ABLE TO PREDICT CLUSTERS FROM THE TRAINED DATA, SO WE USE FIT PREDICT
y_hc = cls.fit_predict()

# %%
plt.scatter(X[y_hc == 0,0], X[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hc == 1,0], X[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_hc == 2,0], X[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_hc == 3,0], X[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_hc == 4,0], X[y_hc == 4, 1], s = 100, c = 'black', label = 'Cluster 5')
plt.title('Clustering Graph')
plt.xlabel('Annual Income')
plt.ylabel('Score')
plt.legend()
plt.show()

## AS WE USE HC, THERE IS NO CENTROID
